# %%
import pandas as pd
from pycaret.classification import *
import os
import matplotlib.pyplot as plt

# Load the dataset
file_path = 'road_acc.csv'
data = pd.read_csv(file_path, encoding='latin1')

# Data Preprocessing
data.columns = data.columns.str.strip()  # Strip leading and trailing spaces from column names
data.replace('-', pd.NA, inplace=True)  # Replace placeholder '-' with NaN
data.fillna('Unknown', inplace=True)  # Fill NaN values with 'Unknown'

# Drop the 'Serial No.' column
if 'Serial No.' in data.columns:
    data.drop(columns=['Serial No.'], inplace=True)

# Standardize the date format in 'Date of accident' column
if 'Date of accident' in data.columns:
    data['Date of accident'] = pd.to_datetime(data['Date of accident'], errors='coerce')

# Remove classes with less than 2 samples in the target column
if 'Cause of accident' in data.columns:
    class_counts = data['Cause of accident'].value_counts()
    valid_classes = class_counts[class_counts >= 2].index
    data = data[data['Cause of accident'].isin(valid_classes)]

# %%
data
# Out:
#    Date of accident Time of accident    Type of accident  \
# 0        2023-03-21          9:00 AM   Head-on collision
# 1        2022-11-22          6:30 AM   Head-on collision
# 2        2022-04-01          5:45 AM  Rear-end collision
# 3        2022-05-26          1:40 PM  Rear-end collision
# 4        2022-06-03         12:00 PM  Rear-end collision
# ..              ...              ...                 ...
# 67       2021-12-20          7:40 AM  Rear-end collision
# 68       2020-02-07          9:00 AM         Overturning
# 69       2020-08-13          3:45 PM   Head on collision
# 70       2020-12-26          8:55 PM          Side swipe
# 71       2019-08-07         10:30 PM  Rear-end collision
#
#       Vehicular involvement  Death  Injury   Cause of accident  \
# 0          CNG- covered van      1       1  Recklessly Driving
# 1        Votvoti-pickup van      2       0  Recklessly Driving
# 2   Truck- mini covered van      2       0  Recklessly Driving
# 3     Unknown- rickshaw van      1       0  Recklessly Driving
# 4     Easy bike- motorcycle      1       0  Recklessly Driving
# ..                      ...    ...     ...                 ...
# 67         Nosimon- korimon      1       0  Recklessly Driving
# 68              Pickup- CNG      1       0  Recklessly Driving
# 69               Pickup-CNG      1       0  Recklessly Driving
# 70             Bus- votvoti      0       3          Overtaking
# 71     Nosimon- covered van      3       0  Recklessly Driving
#
#      Location of Accidents
# 0           Santhia, Pabna
# 1   Vitapara,Santhia Pabna
# 2           Santhia, Pabna
# 3           Santhia, Pabna
# 4           Santhia, Pabna
# ..                     ...
# 67        Ullahpara, Pabna
# 68     Kashinathpur, Pabna
# 69             Bera, Pabna
# 70             Bera, Pabna
# 71          Santhia, Pabna
#
# [72 rows x 8 columns]

# %%
if 'Cause of accident' in data.columns:
    print(data['Cause of accident'].value_counts())
else:
    print("The 'Cause of accident' column is not present in the dataset.")
# Out:
# Cause of accident
# Recklessly Driving    55
# Overtaking             9
# Overspeed              8
# Name: count, dtype: int64

# %%
if 'Date of accident' in data.columns:
    data.drop(columns=['Date of accident'], inplace=True)
    print("Date of accident column dropped.")
else:
    print("The 'Date of accident' column is not present in the dataset.")

# Display the first few rows to confirm the column is dropped
print(data.head())
# Out:
# Date of accident column dropped.
#   Time of accident    Type of accident    Vehicular involvement  Death  \
# 0          9:00 AM   Head-on collision         CNG- covered van      1
# 1          6:30 AM   Head-on collision       Votvoti-pickup van      2
# 2          5:45 AM  Rear-end collision  Truck- mini covered van      2
# 3          1:40 PM  Rear-end collision    Unknown- rickshaw van      1
# 4         12:00 PM  Rear-end collision    Easy bike- motorcycle      1
#
#    Injury   Cause of accident   Location of Accidents
# 0       1  Recklessly Driving          Santhia, Pabna
# 1       0  Recklessly Driving  Vitapara,Santhia Pabna
# 2       0  Recklessly Driving          Santhia, Pabna
# 3       0  Recklessly Driving          Santhia, Pabna
# 4       0  Recklessly Driving          Santhia, Pabna

# %%
data
# Out:
#    Time of accident    Type of accident    Vehicular involvement  Death  \
# 0           9:00 AM   Head-on collision         CNG- covered van      1
# 1           6:30 AM   Head-on collision       Votvoti-pickup van      2
# 2           5:45 AM  Rear-end collision  Truck- mini covered van      2
# 3           1:40 PM  Rear-end collision    Unknown- rickshaw van      1
# 4          12:00 PM  Rear-end collision    Easy bike- motorcycle      1
# ..              ...                 ...                      ...    ...
# 67          7:40 AM  Rear-end collision         Nosimon- korimon      1
# 68          9:00 AM         Overturning              Pickup- CNG      1
# 69          3:45 PM   Head on collision               Pickup-CNG      1
# 70          8:55 PM          Side swipe             Bus- votvoti      0
# 71         10:30 PM  Rear-end collision     Nosimon- covered van      3
#
#     Injury   Cause of accident   Location of Accidents
# 0        1  Recklessly Driving          Santhia, Pabna
# 1        0  Recklessly Driving  Vitapara,Santhia Pabna
# 2        0  Recklessly Driving          Santhia, Pabna
# 3        0  Recklessly Driving          Santhia, Pabna
# 4        0  Recklessly Driving          Santhia, Pabna
# ..     ...                 ...                     ...
# 67       0  Recklessly Driving        Ullahpara, Pabna
# 68       0  Recklessly Driving     Kashinathpur, Pabna
# 69       0  Recklessly Driving             Bera, Pabna
# 70       3          Overtaking             Bera, Pabna
# 71       0  Recklessly Driving          Santhia, Pabna
#
# [72 rows x 7 columns]

# %%
output_file_path = 'road_acc_cleaned.csv'  # Specify the desired output file path
data.to_csv(output_file_path, index=False)  # Save without the index column

print(f"Updated dataset saved to {output_file_path}")
# Out:
# Updated dataset saved to road_acc_cleaned.csv

# %%
from pycaret.classification import *

# %%
clf_setup = setup(
    data=data,
    target='Cause of accident',
    session_id=42,
    log_experiment=False,
    use_gpu=False
)

print("Comparing models...")
best_model = compare_models(sort='AUC', n_select=1)  # Sort models by AUC and select the best one

# Print the best model
print(f"Best model: {best_model}")

# Evaluate the best model
print("Evaluating the best model...")
evaluate_model(best_model)

# Finalize the best model for future use (optional)
final_best_model = finalize_model(best_model)

# Save the best model for future use
model_save_path = 'best_model'
save_model(final_best_model, model_save_path)

# Print model performance metrics
print(f"Best model saved at {model_save_path}.")


# Generate plots using pycaret and save them using plt.save
# Assuming pycaret generates plots using plt, you can save them here
plt.save('model_comparison.png')  # Save model comparison plot
plt.save('classification_report.png')
# Out:
# <style type="text/css">
# #T_3d19b_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_3d19b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3d19b_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_3d19b_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3d19b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3d19b_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_3d19b_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_3d19b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3d19b_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_3d19b_row1_col1" class="data row1 col1" >Cause of accident</td>
#     </tr>
#     <tr>
#       <th id="T_3d19b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3d19b_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_3d19b_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_3d19b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3d19b_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_3d19b_row3_col1" class="data row3 col1" >Overspeed: 0, Overtaking: 1, Recklessly Driving: 2</td>
#     </tr>
#     <tr>
#       <th id="T_3d19b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3d19b_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_3d19b_row4_col1" class="data row4 col1" >(72, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_3d19b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3d19b_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_3d19b_row5_col1" class="data row5 col1" >(72, 20)</td>
#     </tr>
#     <tr>
#       <th id="T_3d19b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3d19b_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_3d19b_row6_col1" class="data row6 col1" >(50, 20)</td>
#     </tr>
#     <tr>
#       <th id="T_3d19b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3d19b_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_3d19b_row7_col1" class="data row7 col1" >(22, 20)</td>
#     </tr>
#     <tr>
#       <th id="T_3d19b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_3d19b_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_3d19b_row8_col1" class="data row8 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_3d19b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_3d19b_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_3d19b_row9_col1" class="data row9 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_3d19b_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_3d19b_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_3d19b_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_3d19b_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_3d19b_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_3d19b_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_3d19b_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_3d19b_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_3d19b_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_3d19b_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_3d19b_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_3d19b_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_3d19b_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_3d19b_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_3d19b_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_3d19b_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_3d19b_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_3d19b_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_3d19b_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_3d19b_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_3d19b_row16_col1" class="data row16 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_3d19b_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_3d19b_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_3d19b_row17_col1" class="data row17 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_3d19b_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_3d19b_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_3d19b_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_3d19b_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_3d19b_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_3d19b_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_3d19b_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_3d19b_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_3d19b_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_3d19b_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_3d19b_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_3d19b_row21_col1" class="data row21 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_3d19b_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_3d19b_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_3d19b_row22_col1" class="data row22 col1" >ddf5</td>
#     </tr>
#   </tbody>
# </table>
# Comparing models...
# <style type="text/css">
# #T_8fe62 th {
#   text-align: left;
# }
# #T_8fe62_row0_col0, #T_8fe62_row0_col1, #T_8fe62_row0_col3, #T_8fe62_row0_col4, #T_8fe62_row0_col5, #T_8fe62_row0_col6, #T_8fe62_row0_col7, #T_8fe62_row1_col0, #T_8fe62_row1_col1, #T_8fe62_row1_col2, #T_8fe62_row1_col3, #T_8fe62_row1_col4, #T_8fe62_row1_col5, #T_8fe62_row1_col6, #T_8fe62_row1_col7, #T_8fe62_row2_col0, #T_8fe62_row2_col1, #T_8fe62_row2_col2, #T_8fe62_row2_col3, #T_8fe62_row2_col4, #T_8fe62_row2_col5, #T_8fe62_row2_col7, #T_8fe62_row3_col0, #T_8fe62_row3_col2, #T_8fe62_row3_col4, #T_8fe62_row3_col5, #T_8fe62_row3_col6, #T_8fe62_row3_col7, #T_8fe62_row4_col0, #T_8fe62_row4_col1, #T_8fe62_row4_col2, #T_8fe62_row4_col3, #T_8fe62_row4_col4, #T_8fe62_row4_col5, #T_8fe62_row4_col6, #T_8fe62_row4_col7, #T_8fe62_row5_col0, #T_8fe62_row5_col2, #T_8fe62_row5_col4, #T_8fe62_row5_col5, #T_8fe62_row5_col6, #T_8fe62_row5_col7, #T_8fe62_row6_col0, #T_8fe62_row6_col1, #T_8fe62_row6_col2, #T_8fe62_row6_col3, #T_8fe62_row6_col4, #T_8fe62_row6_col6, #T_8fe62_row6_col7, #T_8fe62_row7_col0, #T_8fe62_row7_col1, #T_8fe62_row7_col2, #T_8fe62_row7_col3, #T_8fe62_row7_col5, #T_8fe62_row7_col6, #T_8fe62_row8_col0, #T_8fe62_row8_col1, #T_8fe62_row8_col2, #T_8fe62_row8_col3, #T_8fe62_row8_col4, #T_8fe62_row8_col5, #T_8fe62_row8_col6, #T_8fe62_row8_col7, #T_8fe62_row9_col0, #T_8fe62_row9_col2, #T_8fe62_row9_col4, #T_8fe62_row9_col5, #T_8fe62_row9_col6, #T_8fe62_row9_col7, #T_8fe62_row10_col0, #T_8fe62_row10_col1, #T_8fe62_row10_col2, #T_8fe62_row10_col3, #T_8fe62_row10_col4, #T_8fe62_row10_col5, #T_8fe62_row10_col6, #T_8fe62_row10_col7, #T_8fe62_row11_col0, #T_8fe62_row11_col1, #T_8fe62_row11_col2, #T_8fe62_row11_col3, #T_8fe62_row11_col4, #T_8fe62_row11_col5, #T_8fe62_row11_col6, #T_8fe62_row11_col7, #T_8fe62_row12_col0, #T_8fe62_row12_col1, #T_8fe62_row12_col2, #T_8fe62_row12_col3, #T_8fe62_row12_col4, #T_8fe62_row12_col5, #T_8fe62_row12_col6, #T_8fe62_row12_col7 {
#   text-align: left;
# }
# #T_8fe62_row0_col2, #T_8fe62_row2_col6, #T_8fe62_row3_col1, #T_8fe62_row3_col3, #T_8fe62_row5_col1, #T_8fe62_row5_col3, #T_8fe62_row6_col5, #T_8fe62_row7_col4, #T_8fe62_row7_col7, #T_8fe62_row9_col1, #T_8fe62_row9_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_8fe62_row0_col8, #T_8fe62_row1_col8, #T_8fe62_row2_col8, #T_8fe62_row3_col8, #T_8fe62_row4_col8, #T_8fe62_row5_col8, #T_8fe62_row6_col8, #T_8fe62_row8_col8, #T_8fe62_row9_col8, #T_8fe62_row10_col8, #T_8fe62_row11_col8, #T_8fe62_row12_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_8fe62_row7_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_8fe62">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8fe62_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_8fe62_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_8fe62_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_8fe62_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_8fe62_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_8fe62_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_8fe62_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_8fe62_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_8fe62_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8fe62_level0_row0" class="row_heading level0 row0" >xgboost</th>
#       <td id="T_8fe62_row0_col0" class="data row0 col0" >Extreme Gradient Boosting</td>
#       <td id="T_8fe62_row0_col1" class="data row0 col1" >0.2400</td>
#       <td id="T_8fe62_row0_col2" class="data row0 col2" >0.1550</td>
#       <td id="T_8fe62_row0_col3" class="data row0 col3" >0.2400</td>
#       <td id="T_8fe62_row0_col4" class="data row0 col4" >0.5273</td>
#       <td id="T_8fe62_row0_col5" class="data row0 col5" >0.2797</td>
#       <td id="T_8fe62_row0_col6" class="data row0 col6" >-0.0639</td>
#       <td id="T_8fe62_row0_col7" class="data row0 col7" >-0.1110</td>
#       <td id="T_8fe62_row0_col8" class="data row0 col8" >0.1600</td>
#     </tr>
#     <tr>
#       <th id="T_8fe62_level0_row1" class="row_heading level0 row1" >knn</th>
#       <td id="T_8fe62_row1_col0" class="data row1 col0" >K Neighbors Classifier</td>
#       <td id="T_8fe62_row1_col1" class="data row1 col1" >0.7000</td>
#       <td id="T_8fe62_row1_col2" class="data row1 col2" >0.1050</td>
#       <td id="T_8fe62_row1_col3" class="data row1 col3" >0.7000</td>
#       <td id="T_8fe62_row1_col4" class="data row1 col4" >0.5960</td>
#       <td id="T_8fe62_row1_col5" class="data row1 col5" >0.6367</td>
#       <td id="T_8fe62_row1_col6" class="data row1 col6" >0.0073</td>
#       <td id="T_8fe62_row1_col7" class="data row1 col7" >0.0079</td>
#       <td id="T_8fe62_row1_col8" class="data row1 col8" >0.0290</td>
#     </tr>
#     <tr>
#       <th id="T_8fe62_level0_row2" class="row_heading level0 row2" >dt</th>
#       <td id="T_8fe62_row2_col0" class="data row2 col0" >Decision Tree Classifier</td>
#       <td id="T_8fe62_row2_col1" class="data row2 col1" >0.4400</td>
#       <td id="T_8fe62_row2_col2" class="data row2 col2" >0.1000</td>
#       <td id="T_8fe62_row2_col3" class="data row2 col3" >0.4400</td>
#       <td id="T_8fe62_row2_col4" class="data row2 col4" >0.5430</td>
#       <td id="T_8fe62_row2_col5" class="data row2 col5" >0.4385</td>
#       <td id="T_8fe62_row2_col6" class="data row2 col6" >0.0720</td>
#       <td id="T_8fe62_row2_col7" class="data row2 col7" >0.0875</td>
#       <td id="T_8fe62_row2_col8" class="data row2 col8" >0.0280</td>
#     </tr>
#     <tr>
#       <th id="T_8fe62_level0_row3" class="row_heading level0 row3" >lightgbm</th>
#       <td id="T_8fe62_row3_col0" class="data row3 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_8fe62_row3_col1" class="data row3 col1" >0.7600</td>
#       <td id="T_8fe62_row3_col2" class="data row3 col2" >0.1000</td>
#       <td id="T_8fe62_row3_col3" class="data row3 col3" >0.7600</td>
#       <td id="T_8fe62_row3_col4" class="data row3 col4" >0.5840</td>
#       <td id="T_8fe62_row3_col5" class="data row3 col5" >0.6589</td>
#       <td id="T_8fe62_row3_col6" class="data row3 col6" >0.0000</td>
#       <td id="T_8fe62_row3_col7" class="data row3 col7" >0.0000</td>
#       <td id="T_8fe62_row3_col8" class="data row3 col8" >0.0450</td>
#     </tr>
#     <tr>
#       <th id="T_8fe62_level0_row4" class="row_heading level0 row4" >catboost</th>
#       <td id="T_8fe62_row4_col0" class="data row4 col0" >CatBoost Classifier</td>
#       <td id="T_8fe62_row4_col1" class="data row4 col1" >0.4600</td>
#       <td id="T_8fe62_row4_col2" class="data row4 col2" >0.1000</td>
#       <td id="T_8fe62_row4_col3" class="data row4 col3" >0.4600</td>
#       <td id="T_8fe62_row4_col4" class="data row4 col4" >0.6290</td>
#       <td id="T_8fe62_row4_col5" class="data row4 col5" >0.4883</td>
#       <td id="T_8fe62_row4_col6" class="data row4 col6" >0.0590</td>
#       <td id="T_8fe62_row4_col7" class="data row4 col7" >0.0748</td>
#       <td id="T_8fe62_row4_col8" class="data row4 col8" >0.4240</td>
#     </tr>
#     <tr>
#       <th id="T_8fe62_level0_row5" class="row_heading level0 row5" >dummy</th>
#       <td id="T_8fe62_row5_col0" class="data row5 col0" >Dummy Classifier</td>
#       <td id="T_8fe62_row5_col1" class="data row5 col1" >0.7600</td>
#       <td id="T_8fe62_row5_col2" class="data row5 col2" >0.1000</td>
#       <td id="T_8fe62_row5_col3" class="data row5 col3" >0.7600</td>
#       <td id="T_8fe62_row5_col4" class="data row5 col4" >0.5840</td>
#       <td id="T_8fe62_row5_col5" class="data row5 col5" >0.6589</td>
#       <td id="T_8fe62_row5_col6" class="data row5 col6" >0.0000</td>
#       <td id="T_8fe62_row5_col7" class="data row5 col7" >0.0000</td>
#       <td id="T_8fe62_row5_col8" class="data row5 col8" >0.0280</td>
#     </tr>
#     <tr>
#       <th id="T_8fe62_level0_row6" class="row_heading level0 row6" >rf</th>
#       <td id="T_8fe62_r
# Best model: XGBClassifier(base_score=None, booster='gbtree', callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device='cpu', early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=-1,
#               num_parallel_tree=None, objective='multi:softprob', ...)
# Evaluating the best model...
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…
# Transformation Pipeline and Model Successfully Saved
# Best model saved at best_model.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 32
#      27 print(f"Best model saved at {model_save_path}.")
#      30 # Generate plots using pycaret and save them using plt.save
#      31 # Assuming pycaret generates plots using plt, you can save them here
# ---> 32 plt.save('model_comparison.png')  # Save model comparison plot
#      33 plt.save('classification_report.png')
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'save'
